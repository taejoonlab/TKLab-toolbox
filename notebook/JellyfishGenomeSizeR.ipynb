# %% [markdown]
# ## Run JellyFish first
#
# nohup ~/src/jellyfish/jellyfish-2.2.7/bin/jellyfish count -t 16 -C -m 19 -s 24G -o spec1_19mer --min-quality=20 --quality-start=33 *fastq
#
# nohup ~/src/jellyfish/jellyfish-2.2.7/bin/jellyfish histo -o spec1_19mer.histo spec1_19mer

# %%
histo_file <- '../../data/AmphiBase/HYNLE_spec1_19mer.histo'
spec1 <- read.table(histo_file)
plot(spec1[45:200,], type="l")
# Out:
# plot without title
